# %%
from pylab import *
from scipy.integrate import *
# %matplotlib inline

# %%
def ec_mov(x_p,t,epsilon=1.):
    # x_p = x,y,px,py
    r32 = (x_p[0]**2 + x_p[1]**2 )**(1.5)
    dx = x_p[2]
    dy = epsilon*x_p[3] 
    dpx = -x_p[0]/r32
    dpy = -x_p[1]/r32
    return array([dx,dy,dpx,dpy])

def energia(x_p, epsilon=1.):
    # x_p = x,y,px,py
    r = (x_p[0]**2 + x_p[1]**2)**(0.5)
    E = 0.5*(x_p[2]**2 + epsilon*x_p[3]**2) - 1./r
    return E

def cond_ini(alfa,var=0.001):
    angulo = alfa+var*(2.*rand()-1.)
    x,y = cos(angulo),sin(angulo)
    return array([x,y,0.5,0.5])

#Momento en la direccion del radio
def p_rho(x_p):
    # x_p = x,y,px,py
    r = (x_p[:,0]**2 + x_p[:,1]**2)**(0.5)
    x,y,px,py = x_p[:,0],x_p[:,1],x_p[:,2],x_p[:,3]
    p_r = (x*px + y*py)/r
    return p_r,r

# %%
t = linspace(0,10,300)
#energia debe de ser negativa
pto_ini = (0,1,.5,.5)
print "E= ", energia(pto_ini)
sol = odeint(ec_mov,pto_ini,t)
plot(sol[:,0],sol[:,1])

# sol = odeint(ec_mov, )
# Out:
# E=  -0.75

# %%
t = linspace(0,10,500)
for i in range(10):
    pto_ini = [cos(i),sin(i),.5,.5]
    sol = odeint(ec_mov,pto_ini,t)
    plot(sol[:,0],sol[:,1])
    print "E= ", energia(pto_ini), "E_f= ", energia(sol[-1])
show()
# Out:
# E=  -0.75 E_f=  -0.750001185522
# E=  -0.75 E_f=  -0.750010072948
# E=  -0.75 E_f=  -0.750001114517
# E=  -0.75 E_f=  -0.750001293993
# E=  -0.75 E_f=  -0.74989277164
# E=  -0.75 E_f=  -0.750000558983
# E=  -0.75 E_f=  -0.750000781726
# E=  -0.75 E_f=  -0.750023078849
# E=  -0.75 E_f=  -0.750001116598
# E=  -0.75 E_f=  -0.750000569724

# %%
t = linspace(0,10,500)
eps = 1.5
for i in range(10):
    pto_ini = [cos(i),sin(i),.5,.5]
    sol = odeint(ec_mov,pto_ini,t,args=(eps,))
    plot(sol[:,0],sol[:,1])
    print "E= ", energia(pto_ini,eps), "E_f= ", energia(sol[-1])
show()
# Out:
# E=  -0.6875 E_f=  -0.842657443674
# E=  -0.6875 E_f=  -1.11068197248
# E=  -0.6875 E_f=  -0.748202262992
# E=  -0.6875 E_f=  -0.687522999148
# E=  -0.6875 E_f=  -0.776330199871
# E=  -0.6875 E_f=  -0.691399300132
# E=  -0.6875 E_f=  -1.0563996735
# E=  -0.6875 E_f=  -1.21663434672
# E=  -0.6875 E_f=  -0.798314320253
# E=  -0.6875 E_f=  -0.690295828429

# %%
t = arange(0,100,.01)
eps = 1.1
for i in range(10):
    pto_ini = [cos(i),sin(i),.5,.5]
    sol = odeint(ec_mov,pto_ini,t,args=(eps,))
    plot(sol[:,0],sol[:,1])
    print "E= ", energia(pto_ini,eps), "E_f= ", energia(sol[-1])
show()
# Out:
# E=  -0.7375 E_f=  -0.743406936076
# E=  -0.7375 E_f=  -0.747563168914
# E=  -0.7375 E_f=  -0.762813969663
# E=  -0.7375 E_f=  -0.737835033291
# E=  -0.7375 E_f=  -0.757976534587
# E=  -0.7375 E_f=  -0.804786553185
# E=  -0.7375 E_f=  -0.759124638325
# E=  -0.7375 E_f=  -0.737540583286
# E=  -0.7375 E_f=  -0.786980047838
# E=  -0.7375 E_f=  -0.74376317969

# %%
t = arange(0,100,.0001)
eps = 1.1
for i in range(10):
    pto_ini = cond_ini(0)
    sol = odeint(ec_mov, pto_ini, t, args=(eps,),
                atol=1e-9, rtol=1e-9)
    plot(sol[:,0],sol[:,1])
    print "E= ", energia(pto_ini,eps), "E_f= ",energia(sol[-1])
show()
# Out:
# E=  -0.7375 E_f=  -0.756999492174
# E=  -0.7375 E_f=  -0.740145909792
# E=  -0.7375 E_f=  -0.741235245522
# E=  -0.7375 E_f=  -0.746783591393
# E=  -0.7375 E_f=  -0.746436344343
# E=  -0.7375 E_f=  -0.743371856868
# E=  -0.7375 E_f=  -0.741250653907
# E=  -0.7375 E_f=  -0.740779588901
# E=  -0.7375 E_f=  -0.742608437402
# E=  -0.7375 E_f=  -0.756933296124

# %%
def cond_ini(alfa,var=0.001):
    angulo = alfa+var*(2.*rand()-1.)
    x,y = cos(angulo),sin(angulo)
    return array([x,y,1,0])

# %%
t = arange(0,100,.0001)
eps = 1.1
for i in range(10):
    pto_ini = cond_ini(pi/4,0.01)
    sol = odeint(ec_mov, pto_ini, t, args=(eps,),
                atol=1e-9, rtol=1e-9)
    plot(sol[:,0],sol[:,1])
    print "E= ", energia(pto_ini,eps), "E_f= ",energia(sol[-1])
show()
# Out:
# E=  -0.5 E_f=  -0.502524082114
# E=  -0.5 E_f=  -0.502765964436
# E=  -0.5 E_f=  -0.502909769871
# E=  -0.5 E_f=  -0.502611571462
# E=  -0.5 E_f=  -0.501667536551
# E=  -0.5 E_f=  -0.502030266822
# E=  -0.5 E_f=  -0.503011642056
# E=  -0.5 E_f=  -0.501935460104
# E=  -0.5 E_f=  -0.501691114326
# E=  -0.5 E_f=  -0.503013028099

# %%
t = arange(0,100,.0001)
eps = 1
for i in range(10):
    pto_ini = cond_ini(pi/4,0.01)
    plot(pto_ini[0],pto_ini[1],'o')
    sol = odeint(ec_mov,pto_ini,t,args=(eps,),
                atol=1e-9,rtol=1e-9)
    plot(sol[:,0],sol[:,1])
    print "E= ", energia(pto_ini,eps), "E_f= ",energia(sol[-1],eps)
show()
# Out:
# E=  -0.5 E_f=  -0.500000292343
# E=  -0.5 E_f=  -0.500000093706
# E=  -0.5 E_f=  -0.500000209033
# E=  -0.5 E_f=  -0.499999848653
# E=  -0.5 E_f=  -0.50000027579
# E=  -0.5 E_f=  -0.500000303435
# E=  -0.5 E_f=  -0.500000421611
# E=  -0.5 E_f=  -0.500000286544
# E=  -0.5 E_f=  -0.500000350496
# E=  -0.5 E_f=  -0.50000016537

# %%
pr,r = p_rho(sol)
plot(r[0],pr[0],'o')
plot(r,pr)
show()

# %%
def root_trayec(func,pto_i,ti,error=1e-5):
    while abs(pto_i[0])>error:
        tip1 = ti - (pto_i[0]/pto_i[2])
        paso = odeint(func,pto_i,[ti,tip1])
        ti,pto_i = tip1,paso[-1]
    return ti,pto_i

# %%
num = len(t)
raices = zeros(num)
puntos = zeros((num,4))
j=0
for i in range(len(t)-1):
    if (sol[i][0]*sol[i+1][0]) < 0:
        #de toda la trayectoria saca las raices
        raices[j],puntos[j] = root_trayec(ec_mov,sol[i],t[i])
        j+=1
raices,puntos = raices[0:j],puntos[0:j]
xlim([-0.5,2]),ylim([-1.5,1])
plot(puntos[:,0],puntos[:,1],'o')
plot(sol[:,0],sol[:,1])
show()

# %%
pr,r = p_rho(puntos)
xlim([0.2,1.8]),ylim([-1,1])
plot(r[0],pr[0],'o')
plot(r,pr,'o')
show()

# %% [markdown]
# Miercoles 26 de Octubre

# %% [markdown]
# ## $\epsilon = 1$

# %%
t = arange(0,100,.0001)
num, raices, puntos = len(t), zeros(num), zeros((num,4))
N_trayectorias, eps = 2,1.
for i in range(N_trayectorias):
    pto_ini = cond_ini(pi/4,0.01)
    plot(pto_ini[0],pto_ini[1],'o')
    sol = odeint(ec_mov,pto_ini,t,args=(eps,),
                atol=1e-9,rtol=1e-9)
    print "E= ", energia(pto_ini,eps), "E_f= ",energia(sol[-1],eps)
    j=0
    for k in range(len(t)-1):
        if (sol[k][0]*sol[k+1][0]) < 0:
            #de toda la trayectoria saca las raices
            raices[j],puntos[j] = root_trayec(ec_mov,sol[k],t[k])
            j+=1
    raices, puntos = raices[0:j], puntos[0:j]
    pr,r = p_rho(puntos)
    xlim([0.2,1.8]),ylim([-1,1])
    plot(r[0],pr[0],'o')
    plot(r,pr,'o')
show()
# Out:
# E=  -0.5 E_f=  -0.500000368713
# E=  -0.5 E_f=  -0.50000042064
