# %% [markdown]
# # Pasando argumentos de funciones a otras funciones en Python

# %%
from pylab import *
# %matplotlib inline

# %%
def f(x,omega=1):
    return sin(omega*x)

def g(h_de_x,x,args=[]):
    if len(args)==0:
        resultado = exp(-x)*h_de_x(x)
    else:
        resultado = exp(-x)*h_de_x(x,args)
    return resultado

# %%
x=linspace(0,2*pi,200)
for i in range(5):
    plot(x,g(f,x,[i]))
show()
